# %% [markdown]
#  #                 --------Mall Customer Segmentation--------

# %% [raw]
# Customers who come for shopping in a mall can be grouped in a number of ways. Shopping pattern, spending pattern, shopping score, salary etc are some of the factors that can be used to divide the customers into different categories.
#
# The reason for these clusters is to help identify those customers who would be interested in certain products, offers and services. The store may strategize its offerings in such a way that it targets only right customers for specific products. This helps in creating a win-win situation for both the store (in terms of revenue and more customers through customer recommendation) and the customer (discounts, offers, reward points, gifts, etc).

# %% [markdown]
# # Importing the Python Libaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
# Reading the csv file
Mall = pd.read_csv('DS3_C6_S3_MallCustomers_Data_Project.csv')
Mall
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
Mall.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
Mall.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
Mall.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# # Interpretations - We have zero null values in any column.

# %%
#To check the number of rows and columns in the dataset.
Mall.shape
# Out:
# (200, 5)

# %%
# To check for the data types in the dataset.
Mall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# # Annual Income Distribution

# %%
from mpl_toolkits.mplot3d import Axes3D
plt.figure(figsize = (12,8))
sns.set(style = 'whitegrid')
sns.distplot(Mall['Annual Income (k$)'])
plt.title('Distribution of Annual Income (k$)', fontsize = 30)
plt.xlabel('Range of Annual Income (k$)')
plt.ylabel('Count')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Interpretations - Most of the annual income falls between 50K to 85K.

# %% [markdown]
# # AGE DISTRIBUTION:-

# %%
plt.figure(figsize=(12, 8))
sns.set(style = 'whitegrid')
sns.distplot(Mall['Age'])
plt.title('Distribution of Age', fontsize = 40)
plt.xlabel('Range of Age')
plt.ylabel('Count')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Summary - There are customers of a wide variety of ages.

# %% [markdown]
# # SPENDING SCORE DISTRIBUTION

# %%
plt.figure(figsize=(12, 6))
sns.set(style = 'darkgrid')
sns.distplot(Mall['Spending Score (1-100)'])
plt.title('Distribution of Spending Score (1-100)', fontsize = 40)
plt.xlabel('Range of Spending Score (1-100)')
plt.ylabel('Count')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Interpretations - The maximum spending score is in the range of 40 to 60.

# %% [markdown]
# # GENDER ANALYSIS

# %%
genders = Mall.Gender.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(11,4))
sns.barplot(x=genders.index, y=genders.values)
plt.show()

# %% [markdown]
# # Interpretations - Female customers are more compared to male customers.

# %%
sns.distplot(Mall['Age'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Interpretations - Age of the customers follows right skewed normal distrbution.

# %%
sns.distplot(Mall['Annual Income (k$)'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Density'>

# %% [markdown]
# # Interpreations - Annual income of the customers also follows right skewed normal distrbution.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # Interpretations - let's now check for the relationship between different features by using a pairplot.

# %%
sns.pairplot(Mall[[ 'Gender', 'Age', 'Annual Income (k$)','Spending Score (1-100)']])

# %% [markdown]
# # Summary - So we can show in the form of heatmap,to see some of the different part.

# %%
plt.rcParams['figure.figsize'] = (18, 8)
sns.heatmap(Mall[[ 'Gender', 'Age', 'Annual Income (k$)','Spending Score (1-100)']].corr(), cmap = 'magma_r', annot = True, linewidths=.5)
plt.title('Heatmap', fontsize = 20)
plt.show()

# %% [markdown]
# # Note - As we can see there is not much correlation between the features.

# %% [markdown]
# # Gender vs Spending Score

# %%
plt.rcParams['figure.figsize'] = (16, 7)
g = sns.catplot(x="Gender", y="Spending Score (1-100)", kind="violin", inner=None, data=Mall)
sns.swarmplot(x="Gender", y="Spending Score (1-100)", color="c", size=4, data=Mall, ax=g.ax);
plt.title('Gender vs Spending Score', fontsize = 18)
plt.xlabel('Gender')
plt.ylabel('Spending Score (1-100)')
# Out:
# Text(5.710000000000001, 0.5, 'Spending Score (1-100)')

# %% [markdown]
# # Note - violin plot is the hybrid part of box plot and it used to show the peak of data.

# %% [markdown]
# # Gender vs Annual Income

# %%
plt.rcParams['figure.figsize'] = (18, 7)
g = sns.catplot(x="Gender", y="Annual Income (k$)", kind="violin", inner=None, data=Mall)
sns.swarmplot(x="Gender", y="Annual Income (k$)", color="k", size=4, data=Mall, ax=g.ax);
plt.title('Gender vs Annual Income', fontsize = 18)
plt.xlabel('Gender')
plt.ylabel('Annual Income (k$)')
# Out:
# Text(5.960000000000001, 0.5, 'Annual Income (k$)')

# %% [markdown]
# # Gender vs Age

# %%
sns.catplot(x="Gender", y="Age", kind="box", data=Mall);

# %% [markdown]
# # catplot -  shows frequencies (or optionally fractions or percents) of the categories .

# %% [markdown]
# # K-Means Clustering:-

# %% [raw]
# # k-means clustering based on annual income.

# %% [raw]
# # Elbow method to find the optimal number of Clusters.

# %%
data=Mall.iloc[:,[3,4]].values
from sklearn.cluster import KMeans
wcss=[] # within cluster sum of square
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_) #inertia_ = to find the wcss value

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# # WCSS -  is the sum of squares of the distances of each data point in all clusters to their respective centroids.

# %% [markdown]
# # Interpretations - From the above figure, we can see that last most significant slope occurs at k = 5 , hence we will have 5 clusters in this case.

# %%
kmeans=KMeans(n_clusters=5,init='k-means++',random_state=0)
y_kmeans=kmeans.fit_predict(data)

#plotting the the clusters
fig,ax = plt.subplots(figsize=(14,6))
ax.scatter(data[y_kmeans==0,0],data[y_kmeans==0,1],s=100,c='blue',label='Cluster 1')
ax.scatter(data[y_kmeans==1,0],data[y_kmeans==1,1],s=100,c='pink',label='Cluster 2')
ax.scatter(data[y_kmeans==2,0],data[y_kmeans==2,1],s=100,c='green',label='Cluster 3')
ax.scatter(data[y_kmeans==3,0],data[y_kmeans==3,1],s=100,c='teal',label='Cluster 4')
ax.scatter(data[y_kmeans==4,0],data[y_kmeans==4,1],s=100,c='magenta',label='Cluster 5')

ax.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=400,c='cyan',label='Centroid')
plt.title('Cluster Segmentation of Customers')
plt.xlabel('Annual Income(K$)')
plt.ylabel('Spending Score(1-100)')
plt.legend()
plt.show()

# %% [markdown]
# # k-means clustering based on Age:-

# %%
data = Mall.iloc[:,[2,4]].values
from sklearn.cluster import KMeans
wcss=[]  # within cluster sum of square
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)  # inertia_ = to find the wcss value

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# # Interpretations - From the above figure, we can see that last most significant slope occurs at k = 4 , hence we will have 4 clusters in this case.

# %%
kmeans=KMeans(n_clusters=4,init='k-means++',random_state=0)
y_kmeans=kmeans.fit_predict(data)

#Plotting the clusters
fig,ax = plt.subplots(figsize=(14,6))
ax.scatter(data[y_kmeans==0,0],data[y_kmeans==0,1],s=100,c='navy',label='Cluster 1')
ax.scatter(data[y_kmeans==1,0],data[y_kmeans==1,1],s=100,c='blue',label='Cluster 2')
ax.scatter(data[y_kmeans==2,0],data[y_kmeans==2,1],s=100,c='teal',label='Cluster 3')
ax.scatter(data[y_kmeans==3,0],data[y_kmeans==3,1],s=100,c='cyan',label='Cluster 4')

ax.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=400,c='mintcream',label='Centroid')
plt.title('Cluster Segmentation of Customers')
plt.xlabel('Age')
plt.ylabel('Spending Score(1-100)')
plt.legend()
plt.show()

# %% [markdown]
# # CONCLUSION - Using on the k-means clustering we have managed to form different clusters based on different features.
